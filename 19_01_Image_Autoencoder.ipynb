# %% [markdown]
# # Autoencoder 與去除雜訊
#
# [解說 Autoencoder](https://medium.com/%E7%A8%8B%E5%BC%8F%E5%B7%A5%E4%BD%9C%E7%B4%A1/autoencoder-%E4%B8%80-%E8%AA%8D%E8%AD%98%E8%88%87%E7%90%86%E8%A7%A3-725854ab25e8)

# %% [markdown]
# Autoencoder 是一個非常重要的模型，它是很多進階模型的基礎，例如風格轉換(Style Transfer)、影像分割(Image Segmentation)、對抗生成網路(GAN)、WaveNet

# %% [markdown]
# ### Autoencoder 結構
# Autoencoder包含兩部份：
#
# - 編碼器(Encoder)：就是萃取特徵的過程，類似前面CNN模型，不含最後的分類層(Dense)。
# - 解碼器(Decoder)：根據萃取的特徵重建影像。
#
# 編碼再解碼，關鍵在於萃取特徵，取得圖像的主要特徵，其他非特徵的訊號會被濾掉，因此，根據萃取的特徵重建影像，這些非特徵的訊號並不會包含在內，就可以達到去除雜訊的目的，不管圖像、聲音都可以利用此一模型的變形(Variants)去除雜訊。
#
# ![](https://ithelp.ithome.com.tw/upload/images/20200919/200019767P1WHAbToZ.png)
#
# ![](https://miro.medium.com/max/2000/0*l5pTmpzrTagcw3GC)

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as K
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, UpSampling2D

# %%
# GPU 設定為 記憶體動態調整 (dynamic memory allocation)
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## 超參數設定

# %%
np.random.seed(11)
tf.random.set_seed(11)

# 超參數設定
batch_size = 128
max_epochs = 50
filters = [32,32,16]

# %% [markdown]
# ## 取得 MNIST 訓練資料

# %%
# 只取 X ，不取 Y
(x_train, _), (x_test, _) = K.datasets.mnist.load_data()

# 常態化
x_train = x_train / 255.
x_test = x_test / 255.

# 加一維：色彩
x_train = np.reshape(x_train, (len(x_train),28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %% [markdown]
# ## 在既有圖片加雜訊

# %%
# 在既有圖片加雜訊
noise = 0.5
# 隨機加雜訊
x_train_noisy = x_train + noise * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# 加完裁切數值，不大於 1
x_train_noisy = np.clip(x_train_noisy, 0, 1)
x_test_noisy = np.clip(x_test_noisy, 0, 1)

x_train_noisy = x_train_noisy.astype('float32')
x_test_noisy = x_test_noisy.astype('float32')

#print(x_test_noisy[1].dtype)

# %% [markdown]
# ## 建立編碼器(Encoder)、解碼器(Decoder) 模型

# %%
# 編碼器(Encoder)
class Encoder(K.layers.Layer):
    def __init__(self, filters):
        super(Encoder, self).__init__()
        self.conv1 = Conv2D(filters=filters[0], kernel_size=3, strides=1, activation='relu', padding='same')
        self.conv2 = Conv2D(filters=filters[1], kernel_size=3, strides=1, activation='relu', padding='same')
        self.conv3 = Conv2D(filters=filters[2], kernel_size=3, strides=1, activation='relu', padding='same')
        self.pool = MaxPooling2D((2, 2), padding='same')
               
    
    def call(self, input_features):
        x = self.conv1(input_features)
        #print("Ex1", x.shape)
        x = self.pool(x)
        #print("Ex2", x.shape)
        x = self.conv2(x)
        x = self.pool(x)
        x = self.conv3(x)
        x = self.pool(x)
        return x

# 解碼器(Decoder)
# upsampling與池化層(pooling)相反，把一個點變成一個面
class Decoder(K.layers.Layer):
    def __init__(self, filters):
        super(Decoder, self).__init__()
        self.conv1 = Conv2D(filters=filters[2], kernel_size=3, strides=1, activation='relu', padding='same')
        self.conv2 = Conv2D(filters=filters[1], kernel_size=3, strides=1, activation='relu', padding='same')
        self.conv3 = Conv2D(filters=filters[0], kernel_size=3, strides=1, activation='relu', padding='valid')
        self.conv4 = Conv2D(1, 3, 1, activation='sigmoid', padding='same')
        self.upsample = UpSampling2D((2, 2))
  
    def call(self, encoded):
        x = self.conv1(encoded)
        # 上採樣
        x = self.upsample(x)

        x = self.conv2(x)
        x = self.upsample(x)
        
        x = self.conv3(x)
        x = self.upsample(x)
        
        return self.conv4(x)

# %% [markdown]
# ## Autoencoder 結構，結合編碼器(Encoder)、解碼器(Decoder) 模型

# %%
class Autoencoder(K.Model):
    def __init__(self, filters):
        super(Autoencoder, self).__init__()
        self.loss = []
        self.encoder = Encoder(filters)
        self.decoder = Decoder(filters)

    def call(self, input_features):
        #print(input_features.shape)
        encoded = self.encoder(input_features)
        #print(encoded.shape)
        reconstructed = self.decoder(encoded)
        #print(reconstructed.shape)
        return reconstructed

# %% [markdown]
# ## 訓練模型

# %%
model = Autoencoder(filters)

model.compile(loss='binary_crossentropy', optimizer='adam')
# 原始圖片 x_train 及 x_test 可當作用來比對 loss的 label
loss = model.fit(x_train_noisy,
                x_train,
                validation_data=(x_test_noisy, x_test),
                epochs=max_epochs,
                batch_size=batch_size)
# Out:
# Epoch 1/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2051 - val_loss: 0.1506
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1419 - val_loss: 0.1326
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1288 - val_loss: 0.1239
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1224 - val_loss: 0.1197
# Epoch 5/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1181 - val_loss: 0.1155
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1152 - val_loss: 0.1129
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1128 - val_loss: 0.1111
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1113 - val_loss: 0.1101
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1098 - val_loss: 0.1083
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1087 - val_loss: 0.1080
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1076 - val_loss: 0.1062
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1068 - val_loss: 0.1060
# Epoch 13/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1061 - val_loss: 0.1051
# Epoch 14/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1056 - val_loss: 0.1042
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1049 - val_loss: 0.1037
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1044 - val_loss: 0.1037
# Epoch 17/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1039 - val_loss: 0.1032
# Epoch 18/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1034 - val_loss: 0.1027
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1031 - val_loss: 0.1020
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1027 - val_loss: 0.1017
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1024 - val_loss: 0.1016
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1021 - val_loss: 0.1017
# Epoch 23/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1020 - val_loss: 0.1021
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1017 - val_loss: 0.1012
# Epoch 25/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1014 - val_loss: 0.1009
# Epoch 26/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1012 - val_loss: 0.1005
# Epoch 27/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1009 - val_loss: 0.1006
# Epoch 28/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1008 - val_loss: 0.1009
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1006 - val_loss: 0.1002
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1005 - val_loss: 0.1003
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1004 - val_loss: 0.1007
# Epoch 32/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1002 - val_loss: 0.1011
# Epoch 33/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1000 - val_loss: 0.0999
# Epoch 34/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0999 - val_loss: 0.0995
# Epoch 35/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1000 - val_loss: 0.0998
# Epoch 36/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0997 - val_loss: 0.0995
# Epoch 37/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0996 - val_loss: 0.0991
# Epoch 38/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0995 - val_loss: 0.0990
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0995 - val_loss: 0.0989
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0994 - val_loss: 0.0992
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0993 - val_loss: 0.0988
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0992 - val_loss: 0.0990
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0992 - val_loss: 0.0989
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0990 - val_loss: 0.0987
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0990 - val_loss: 0.0990
# Epoch 46/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0990 - val_loss: 0.0987
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0989 - val_loss: 0.0989
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0988 - val_loss: 0.0984
# Epoch 49/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0987 - val_loss: 0.0990
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0987 - val_loss: 0.0986

# %% [markdown]
# ## 繪製損失函數

# %%
# 繪製損失函數
plt.plot(range(max_epochs), loss.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ## 比較加了雜訊的圖與訓練後的圖

# %%
number = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for index in range(number):
    # display original
    ax = plt.subplot(2, number, index + 1)
    plt.imshow(x_test_noisy[index].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, number, index + 1 + number)
    plt.imshow(tf.reshape(model(x_test_noisy)[index], (28, 28)), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
