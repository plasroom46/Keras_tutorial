# %%
# pip install opencv-python
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # 模糊化(Blur)

# %% [markdown]
# 卷積(Convolution)的特徵萃取：利用不同的卷積核(kernel)作卷積運算，會有不同的效果，例如，卷積核如下，將像素以週圍像素的平均值取代，會造成模糊化的效果，目的是將去躁(Denose)，將雜訊去除。
#
# 模糊化的卷積核(kernel)
#
# ![](https://ithelp.ithome.com.tw/upload/images/20200911/20001976QGCjU8i8zf.png)

# %%
smallBlur = np.ones((3, 3), dtype="float") * (1.0 / (3 * 3))
smallBlur
# Out:
# array([[0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111]])

# %%
# 使用cv2.filter2D進行convolution
image_name = './0_images/conv_org.png'
image = cv2.imread(image_name)
smallBlur = np.ones((7, 7), dtype="float") * (1.0 / (7 * 7))
result = cv2.filter2D(image, -1, smallBlur)

# %%
# 顯示原圖與處理結果
plt.figure(figsize=(10,6))
plt.subplot(121)
plt.imshow(image)
plt.subplot(122)
plt.imshow(result)
plt.show()

# %% [markdown]
# # 銳化(Sharpen)

# %%
# construct a sharpening filter
sharpen = np.array((
	[0, -1, 0],
	[-1, 5, -1],
	[0, -1, 0]), dtype="int")

result = cv2.filter2D(image, -1, sharpen)

# %%
# 顯示原圖與處理結果
plt.figure(figsize=(10,6))
plt.subplot(121)
plt.imshow(image)
plt.subplot(122)
plt.imshow(result)
plt.show()

# %% [markdown]
# # 邊緣偵測(Edge detection)

# %%
# construct the Laplacian kernel used to detect edge-like regions of an image
laplacian = np.array((
	[0, 1, 0],
	[1, -4, 1],
	[0, 1, 0]), dtype="int")

result = cv2.filter2D(image, -1, laplacian)

# %%
# 顯示原圖與處理結果
plt.figure(figsize=(10,6))
plt.subplot(121)
plt.imshow(image)
plt.subplot(122)
plt.imshow(result)
plt.show()

# %% [markdown]
# # X軸邊緣偵測

# %%
# construct the Sobel x-axis kernel
sobelX = np.array((
	[-1, 0, 1],
	[-2, 0, 2],
	[-1, 0, 1]), dtype="int")

result = cv2.filter2D(image, -1, sobelX)

# %%
# 顯示原圖與處理結果
plt.figure(figsize=(10,6))
plt.subplot(121)
plt.imshow(image)
plt.subplot(122)
plt.imshow(result)
plt.show()

# %% [markdown]
# # Y軸邊緣偵測

# %%
# construct the Sobel x-axis kernel
sobelY = np.array((
	[-1, -2, -1],
	[0, 0, 0],
	[1, 2, 1]), dtype="int")

result = cv2.filter2D(image, -1, sobelY)

# %%
# 顯示原圖與處理結果
plt.figure(figsize=(10,6))
plt.subplot(121)
plt.imshow(image)
plt.subplot(122)
plt.imshow(result)
plt.show()
